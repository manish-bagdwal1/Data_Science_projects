# %% [markdown]
# <center><img src="https://github.com/insaid2018/Term-1/blob/master/Images/INSAID_Full%20Logo.png?raw=true" width="378" height="180" /></center>
#
# # <center> Emotions NLP Classification </center>

# %% [markdown]
# ---
# ## Table of Contents
# ---
#
# 1. [Problem Statement](#section1)<br>
# 2. [Importing Packages](#section2)<br>
# 3. [Loading Data](#section3)<br>
#   - 3.1 [Description of the Dataset](#section301)<br>
#   - 3.2 [Basic EDA](#section302)<br>
# 4. [Data Preprocessing](#section4)<br>
# 5. [Model Building](#section5)<br>
# 6. [Prediction on test set](#section6)<br>
# 7. [Conclusion](#section7)

# %% [markdown]
# <a name=section1></a>
#
# ---
# ## 1. Problem Statement
# ---
#
# - A ROBOTICS tech company is making a robot especially for the purpose of
#  **detecting emotions** from the human statements.
# - They want to detect some of the basic **emotions** like joy, sadness , fear , anger etc.
#
# <br>
# <center><img src="https://www.verywellmind.com/thmb/YwJYR3y0yhvZjAeHyPZXPVX6V1E=/1500x1000/filters:no_upscale():max_bytes(150000):strip_icc()/an-overview-of-the-types-of-emotions-4163976-01-474bb455cfe74c3cb98ea46113e3108b.png" width="700px" height="450px"/></center>
# <br>
#
# - The current process suffers from the following issues:
#
#   - To detect emotions, they have to put an **extra effort** to classify each statements from various scenario
#
#   - This process is very **slow**, **time-consuming**, and **inefficient**.
#
# - The company has hired you as data science consultants.
#
# - They want to **automate** the emotions classification process to make it more efficient and deployable on robot.

# %% [markdown]
# <a name=section2></a>
#
# ---
# ## 2. Importing Packages
# ---

# %%
# for basic data processesing
import numpy as np 
import pandas as pd  

# for warnings
import warnings
warnings.filterwarnings('ignore')

# for plotting
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
# %config InlineBackend.figure_format = 'retina'

# for preprocessing
from tqdm._tqdm_notebook import tqdm_notebook
import text_hammer as th

# for text data preparation
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences

# for Label encoding
from tensorflow.keras.utils import to_categorical


# for getting weight vectors
import gensim.downloader as api

# # model buliding layers
from tensorflow.keras.models import Sequential 
from tensorflow.keras.layers import Dense, LSTM, Embedding,Bidirectional
import tensorflow
from tensorflow.compat.v1.keras.layers import CuDNNLSTM,CuDNNGRU
from tensorflow.keras.layers import Dropout

# for callbacks
from keras.callbacks import EarlyStopping, ModelCheckpoint

# for metrics
from sklearn import metrics
from sklearn.metrics import accuracy_score

# %% [markdown]
# <a name=section3></a>
#
# ---
# ## 3. Loading Data
# ---

# %%
# loading train data
train_data=pd.read_csv("emotion_train.csv")
train_data.head()
# Out:
#       Id                                              Input Sentiment
# 0   6491              i feel extremely discontent right now   sadness
# 1   7081  i havent gone a week without exaggerated eyeli...   sadness
# 2   7598  i feel so thrilled to share with my fans becau...       joy
# 3  15874  i wanted to because he loves me and i feel lik...      love
# 4  12871  i feel we should not be supporting these rebel...      love

# %%
# loading test data
test_data=pd.read_csv("emotion_test.csv")
test_data.head()
# Out:
#       Id                                              Input
# 0  10779  i could almost feel it as the flames singed an...
# 1   2247  i realise im sounding surprisingly like every ...
# 2  11765  i have all of that obviously because of what i...
# 3  14390  i cannot speak for others but all i know is i ...
# 4    388  im pretty happy but a little on the nauseated ...

# %% [markdown]
# <a name=section301></a>
# ### 3.1 Data Description

# %%
train_data.shape
# Out:
# (14400, 3)

# %%
test_data.shape
# Out:
# (3600, 2)

# %% [markdown]
# **Observation**
# - There are **14400 rows** in train data with **3 columns**
# - There are **3600 rows** in test data with **2 columns**

# %% [markdown]
# <a name=section302></a>
# ### 3.2 Basic EDA

# %%
sns.countplot(train_data.Sentiment)
plt.show()

# %% [markdown]
# **Observation**
# - **Most** of the statements are of **joy** .
# - The **least** statements are of **surprise**.
# - The sad statements are also in significant numbers.

# %%
# getting lenght of each sentence
length_of_sen= [len(ele) for ele in train_data['Input']]

# %%
plt.plot(length_of_sen)
plt.show()

# %% [markdown]
# **Observation**
# - We can easily see **most** of the **sentences** have more **200 words**.
# - There are also **significant** amount of **sentences** having length more than **250 words**.
# - From the plot it also seems like there are **few sentences** touching **300 word** length.

# %% [markdown]
# <a name=section4></a>
#
# ---
# ## 4. Data Preprocessing
# ---

# %%
# %%time

def text_preprocessing(df,col_name):
    column = col_name
    df[column] = df[column].progress_apply(lambda x:str(x).lower()) # lower sentences
    df[column] = df[column].progress_apply(lambda x: th.cont_exp(x)) #you're -> you are; i'm -> i am
    df[column] = df[column].progress_apply(lambda x: th.remove_emails(x))
    df[column] = df[column].progress_apply(lambda x: th.remove_html_tags(x)) # removing html tags

# df[column] = df[column].progress_apply(lambda x: ps.remove_stopwords(x))  
# here we can remove stop-words but in this case removing not, and ,can change the meaning of context 

    df[column] = df[column].progress_apply(lambda x: th.remove_special_chars(x)) # removing special characters
    df[column] = df[column].progress_apply(lambda x: th.remove_accented_chars(x)) 
    df[column] = df[column].progress_apply(lambda x: th.make_base(x)) # ran -> run
    return(df)
# Out:
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 6.91 µs

# %%
# cleaning train data
cleaned_train_data = text_preprocessing(train_data, 'Input')
# Out:
#   0%|          | 0/14400 [00:00<?, ?it/s]
#   0%|          | 0/14400 [00:00<?, ?it/s]
#   0%|          | 0/14400 [00:00<?, ?it/s]
#   0%|          | 0/14400 [00:00<?, ?it/s]
#   0%|          | 0/14400 [00:00<?, ?it/s]
#   0%|          | 0/14400 [00:00<?, ?it/s]
#   0%|          | 0/14400 [00:00<?, ?it/s]

# %%
cleaned_train_data.head()
# Out:
#       Id                                              Input Sentiment
# 0   6491              i feel extremely discontent right now   sadness
# 1   7081  i have not go a week without exaggerated eyeli...   sadness
# 2   7598  i feel so thrilled to share with my fan becaus...       joy
# 3  15874  i want to because he love me and i feel like i...      love
# 4  12871  i feel we should not be support these rebel in...      love

# %%
# cleaning test data
cleaned_test_data = text_preprocessing(test_data, 'Input')
# Out:
#   0%|          | 0/3600 [00:00<?, ?it/s]
#   0%|          | 0/3600 [00:00<?, ?it/s]
#   0%|          | 0/3600 [00:00<?, ?it/s]
#   0%|          | 0/3600 [00:00<?, ?it/s]
#   0%|          | 0/3600 [00:00<?, ?it/s]
#   0%|          | 0/3600 [00:00<?, ?it/s]
#   0%|          | 0/3600 [00:00<?, ?it/s]

# %%
cleaned_test_data.head()
# Out:
#       Id                                              Input
# 0  10779  i could almost feel it as the flame singe and ...
# 1   2247  i realise i m sound surprisingly like every ot...
# 2  11765  i have all of that obviously because of what i...
# 3  14390  i can not speak for other but all i know is i ...
# 4    388  i m pretty happy but a little on the nauseated...

# %% [markdown]
# ##### Converting the text output  into integer (label encoding )

# %%
cleaned_train_data['Sentiment']=cleaned_train_data.Sentiment.replace({'joy':0,'anger':1,'love':2,'sadness':3,'fear':4,'surprise':5})

# %%
cleaned_train_data.head()
# Out:
#       Id                                              Input  Sentiment
# 0   6491              i feel extremely discontent right now          3
# 1   7081  i have not go a week without exaggerated eyeli...          3
# 2   7598  i feel so thrilled to share with my fan becaus...          0
# 3  15874  i want to because he love me and i feel like i...          2
# 4  12871  i feel we should not be support these rebel in...          2

# %% [markdown]
# **Observation**
# - Here we can see our has been cleaned and the **label encoding** of **Sentiment** has been done

# %%
# tokenisation
num_words = 10000 # this means 10000 unique words can be taken 
tokenizer=Tokenizer(num_words,lower=True)
tokenizer.fit_on_texts(cleaned_train_data['Input'])

# %%
len(tokenizer.word_index) # this is whole unique words in our corpus
# but we are taking only 10000 words in our model
# Out:
# 11504

# %%
# padding
X_train=tokenizer.texts_to_sequences(cleaned_train_data['Input']) # this converts texts into some numeric sequences 
X_train_pad=pad_sequences(X_train,maxlen=300,padding='post') # this makes the length of all numeric sequences equal 

X_test = tokenizer.texts_to_sequences(cleaned_test_data.Input)
X_test_pad = pad_sequences(X_test, maxlen = 300, padding = 'post')

# %%
# 
y_train = to_categorical(cleaned_train_data.Sentiment.values)

# %% [markdown]
# ### Loading Embeding file

# %%
glove_gensim  = api.load('glove-wiki-gigaword-100') #100 dimension
# more dimension means more deep meaning of words but it may take longer time to download
# Out:
# [==================================================] 100.0% 128.1/128.1MB downloaded

# %%
# Creating a word2Vec weight matrix
vector_size = 100
gensim_weight_matrix = np.zeros((num_words ,vector_size))
gensim_weight_matrix.shape

for word, index in tokenizer.word_index.items():
    if index < num_words: # since index starts with zero 
        if word in glove_gensim.wv.vocab:
            gensim_weight_matrix[index] = glove_gensim[word]
        else:
            gensim_weight_matrix[index] = np.zeros(100)

# %%
gensim_weight_matrix.shape
# Out:
# (10000, 100)

# %% [markdown]
# <a name=section5></a>
#
# ---
# ## 5.  Model Building
# ---

# %% [markdown]
# ### Build the Model
#
# - Let's build our model.
#
# - Here, we'll use a `Sequential` model with CuDNNLSTM and Dense layers.
# - We add first layers as embedding layers to feed in our vectors to the LSTM layers.

# %%
EMBEDDING_DIM = 100 # this means the embedding layer will create  a vector in 100 dimension
model = Sequential()
model.add(Embedding(input_dim = num_words,# the whole vocabulary size 
                          output_dim = EMBEDDING_DIM, # vector space dimension
                          input_length= X_train_pad.shape[1], # max_len of text sequence
                          weights = [gensim_weight_matrix],trainable = False))
model.add(Dropout(0.2))
model.add(Bidirectional(CuDNNLSTM(100,return_sequences=True)))
model.add(Dropout(0.2))
model.add(Bidirectional(CuDNNLSTM(200,return_sequences=True)))
model.add(Dropout(0.2))
model.add(Bidirectional(CuDNNLSTM(100,return_sequences=False)))
model.add(Dense(6, activation = 'softmax'))
model.compile(loss = 'categorical_crossentropy', optimizer = 'adam',metrics = 'accuracy')

# %%
#using callbacks
es = EarlyStopping(monitor = 'val_loss', mode = 'min', verbose = 1, patience = 5)
mc = ModelCheckpoint('./model.h5', monitor = 'val_accuracy', mode = 'max', verbose = 1, save_best_only = True)

# %%
# training model
history = model.fit(X_train_pad,y_train, epochs = 25, batch_size = 120, validation_split=0.2 ,verbose = 1, callbacks= [es, mc]  )
# Out:
# Epoch 1/25
# 96/96 [==============================] - ETA: 0s - loss: 1.4428 - accuracy: 0.4430
# Epoch 00001: val_accuracy improved from -inf to 0.52535, saving model to ./model.h5
# 96/96 [==============================] - 65s 589ms/step - loss: 1.4428 - accuracy: 0.4430 - val_loss: 1.2933 - val_accuracy: 0.5253
# Epoch 2/25
# 96/96 [==============================] - ETA: 0s - loss: 1.2175 - accuracy: 0.5435
# Epoch 00002: val_accuracy improved from 0.52535 to 0.61007, saving model to ./model.h5
# 96/96 [==============================] - 55s 578ms/step - loss: 1.2175 - accuracy: 0.5435 - val_loss: 1.0915 - val_accuracy: 0.6101
# Epoch 3/25
# 96/96 [==============================] - ETA: 0s - loss: 0.9971 - accuracy: 0.6388
# Epoch 00003: val_accuracy improved from 0.61007 to 0.71111, saving model to ./model.h5
# 96/96 [==============================] - 56s 587ms/step - loss: 0.9971 - accuracy: 0.6388 - val_loss: 0.8319 - val_accuracy: 0.7111
# Epoch 4/25
# 96/96 [==============================] - ETA: 0s - loss: 0.8064 - accuracy: 0.7043
# Epoch 00004: val_accuracy improved from 0.71111 to 0.76042, saving model to ./model.h5
# 96/96 [==============================] - 56s 584ms/step - loss: 0.8064 - accuracy: 0.7043 - val_loss: 0.6636 - val_accuracy: 0.7604
# Epoch 5/25
# 96/96 [==============================] - ETA: 0s - loss: 0.6659 - accuracy: 0.7543
# Epoch 00005: val_accuracy improved from 0.76042 to 0.78715, saving model to ./model.h5
# 96/96 [==============================] - 56s 584ms/step - loss: 0.6659 - accuracy: 0.7543 - val_loss: 0.5823 - val_accuracy: 0.7872
# Epoch 6/25
# 96/96 [==============================] - ETA: 0s - loss: 0.6057 - accuracy: 0.7723
# Epoch 00006: val_accuracy improved from 0.78715 to 0.80069, saving model to ./model.h5
# 96/96 [==============================] - 56s 580ms/step - loss: 0.6057 - accuracy: 0.7723 - val_loss: 0.5283 - val_accuracy: 0.8007
# Epoch 7/25
# 96/96 [==============================] - ETA: 0s - loss: 0.5196 - accuracy: 0.8071
# Epoch 00007: val_accuracy improved from 0.80069 to 0.85104, saving model to ./model.h5
# 96/96 [==============================] - 55s 573ms/step - loss: 0.5196 - accuracy: 0.8071 - val_loss: 0.4271 - val_accuracy: 0.8510
# Epoch 8/25
# 96/96 [==============================] - ETA: 0s - loss: 0.4610 - accuracy: 0.8299
# Epoch 00008: val_accuracy did not improve from 0.85104
# 96/96 [==============================] - 56s 582ms/step - loss: 0.4610 - accuracy: 0.8299 - val_loss: 0.4290 - val_accuracy: 0.8448
# Epoch 9/25
# 96/96 [==============================] - ETA: 0s - loss: 0.4133 - accuracy: 0.8444
# Epoch 00009: val_accuracy improved from 0.85104 to 0.86979, saving model to ./model.h5
# 96/96 [==============================] - 55s 573ms/step - loss: 0.4133 - accuracy: 0.8444 - val_loss: 0.3477 - val_accuracy: 0.8698
# Epoch 10/25
# 96/96 [==============================] - ETA: 0s - loss: 0.3655 - accuracy: 0.8604
# Epoch 00010: val_accuracy improved from 0.86979 to 0.87465, saving model to ./model.h5
# 96/96 [==============================] - 56s 581ms/step - loss: 0.3655 - accuracy: 0.8604 - val_loss: 0.3518 - val_accuracy: 0.8747
# Epoch 11/25
# 96/96 [==============================] - ETA: 0s - loss: 0.3354 - accuracy: 0.8717
# Epoch 00011: val_accuracy improved from 0.87465 to 0.87500, saving model to ./model.h5
# 96/96 [==============================] - 56s 582ms/step - loss: 0.3354 - accuracy: 0.8717 - val_loss: 0.3289 - val_accuracy: 0.8750
# Epoch 12/25
# 96/96 [==============================] - ETA: 0s - loss: 0.3033 - accuracy: 0.8827
# Epoch 00012: val_accuracy improved from 0.87500 to 0.88368, saving model to ./model.h5
# 96/96 [==============================] - 55s 571ms/step - loss: 0.3033 - accuracy: 0.8827 - val_loss: 0.3043 - val_accuracy: 0.8837
# Epoch 13/25
# 96/96 [==============================] - ETA: 0s - loss: 0.2754 - accuracy: 0.8932
# Epoch 00013: val_accuracy improved from 0.88368 to 0.88993, saving model to ./model.h5
# 96/96 [==============================] - 56s 581ms/step - loss: 0.2754 - accuracy: 0.8932 - val_loss: 0.2906 - val_accuracy: 0.8899
# Epoch 14/25
# 96/96 [==============================] - ETA: 0s - loss: 0.2590 - accuracy: 0.8979
# Epoch 00014: val_accuracy did not improve from 0.88993
# 96/96 [==============================] - 55s 578ms/step - loss: 0.2590 - accuracy: 0.8979 - val_loss: 0.2961 - val_accuracy: 0.8868
# Epoch 15/25
# 96/96 [==============================] - ETA: 0s - loss: 0.2391 - accuracy: 0.9046
# Epoch 00015: val_accuracy improved from 0.88993 to 0.89410, saving model to ./model.h5
# 96/96 [==============================] - 55s 571ms/step - loss: 0.2391 - accuracy: 0.9046 - val_loss: 0.2745 - val_accuracy: 0.8941
# Epoch 16/25
# 96/96 [==============================] - ETA: 0s - loss: 0.2371 - accuracy: 0.9061
# Epoch 00016: val_accuracy improved from 0.89410 to 0.89444, saving model to ./model.h5
# 96/96 [==============================] - 56s 580ms/step - loss: 0.2371 - accuracy: 0.9061 - val_loss: 0.2797 - val_accuracy: 0.8944
# Epoch 17/25
# 96/96 [==============================] - ETA: 0s - loss: 0.2122 - accuracy: 0.9138
# Epoch 00017: val_accuracy improved from 0.89444 to 0.89896, saving model to ./model.h5
# 96/96 [==============================] - 55s 576ms/step - loss: 0.2122 - accuracy: 0.9138 - val_loss: 0.2618 - val_accuracy: 0.8990
# Epoch 18/25
# 96/96 [==============================] - ETA: 0s - loss: 0.1987 - accuracy: 0.9219
# Epoch 00018: val_accuracy did not improve from 0.89896
# 96/96 [==============================] - 55s 578ms/step - loss: 0.1987 - accuracy: 0.9219 - val_loss: 0.2680 - val_accuracy: 0.8941
# Epoch 19/25
# 96/96 [==============================] - ETA: 0s - loss: 0.1901 - accuracy: 0.9247
# Epoch 00019: val_accuracy did not improve from 0.89896
# 96/96 [==============================] - 56s 579ms/step - loss: 0.1901 - accuracy: 0.9247 - val_loss: 0.2649 - val_accuracy: 0.8903
# Epoch 20/25
# 96/96 [==============================] - ETA: 0s - loss: 0.1891 - accuracy: 0.9230
# Epoch 00020: val_accuracy did not improve from 0.89896
# 96/96 [==============================] - 55s 578ms/step - loss: 0.1891 - accuracy: 0.9230 - val_loss: 0.2664 - val_accuracy: 0.8948
# Epoch 21/25
# 96/96 [==============================] - ETA: 0s - loss: 0.1735 - accuracy: 0.9306
# Epoch 00021: val_accuracy improved from 0.89896 to 0.90035, saving model to ./model.h5
# 96/96 [==============================] - 56s 579ms/step - loss: 0.1735 - accuracy: 0.9306 - val_loss: 0.2715 - val_accuracy: 0.9003
# Epoch 22/25
# 96/96 [==============================] - ETA: 0s - loss: 0.1541 - accuracy: 0.9371
# Epoch 00022: val_accuracy improved from 0.90035 to 0.90104, saving model to ./model.h5
# 96/96 [==============================] - 55s 571ms/step - loss: 0.1541 - accuracy: 0.9371 - val_loss: 0.2848 - val_accuracy: 0.9010
# Epoch 00022: early stopping

# %% [markdown]
# **Observation**
# - Using Bi-directional LSTM we achieved **val accuracy of 90 %**

# %%
# plot of train vs validation
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(22)

plt.figure(figsize=(18, 12))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# **Observation**
# - Here we can see our model is peforming good since both **accuracy and loss**
# are increasing and decreasing respectively.
# - Since we see both train and val loss is comparable that also means model is **not overfitting**.

# %% [markdown]
# <a name=section6></a>
#
# ---
# ## 6. Prediction on test set
# ---

# %%
predict_y = model.predict(X_test_pad) # predict using model
classes_y = np.argmax(predict_y,axis=1) # getting class labels

# %%
submission = pd.DataFrame({'Id':test_data['Id'],'Sentiment':classes_y}) # our submission file

# %%
submission.head()
# Out:
#       Id  Sentiment
# 0  10779          2
# 1   2247          3
# 2  11765          0
# 3  14390          0
# 4    388          0

# %%
submission['Sentiment']= submission.Sentiment.replace({0:'joy',1:'anger',2:'love',3:'sadness',4:'fear',5:'surprise'}) # replacing our no labels with actual labels

# %%
submission.to_csv('Submission.csv',header=False,index=False) # submitting our file

# %%
# original y test labels
y_df = pd.read_csv('/content/emotion_y_test.csv', names=['Id', 'Sentiment'])
y_df.head()
# Out:
#       Id Sentiment
# 0  10779      fear
# 1   2247   sadness
# 2  11765       joy
# 3  14390       joy
# 4    388       joy

# %%
print('Accuracy score for test data is:', accuracy_score(y_df['Sentiment'],submission['Sentiment']))
# Out:
# Accuracy score for test data is: 0.9002777777777777

# %% [markdown]
# <a name=section7></a>
#
# ---
# ## 7. Conclusion
# ---
#
# - We used **pretrained embedding glove** to improve our model performance.
# - We also used **CuDNN** , which is a faster implimentation of **LSTM**.
# - We saw how **cleaning** the data helped our accuracy.
# - Also using **dropouts** helped our model.
